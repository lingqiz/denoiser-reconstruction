# %%
import main
from utils.dataset import ISLVRC

# %%
# sample image patches from ISLVRC
islvrc = ISLVRC(main.args)
print(islvrc.train_set().shape)
print(islvrc.train_set().dtype)
# Out:
# (298667, 64, 64, 3)
# float32

# %%
print(islvrc.train_set().min())
print(islvrc.train_set().max())
# Out:
# 0.0
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_sample = islvrc.train_set().shape[0]

fig, axs = plt.subplots(2, 4, figsize=(10, 5), sharex=True, sharey=True)
for idx, ax in zip(range(8), axs.flat):
    ax.imshow(islvrc.train_set()[np.random.randint(n_sample), :, :, :])

fig.tight_layout()

# %%
from models.denoiser import Denoiser
from utils.training import train_denoiser

import warnings
warnings.filterwarnings("ignore", 
    message="Setting attributes on ParameterDict is not supported.")

# %%
model = Denoiser(main.args)
print('number of parameters is ' , sum(p.numel() for p in model.parameters()))
# Out:
# number of parameters is  668160

# %%
train_denoiser(islvrc.train_set(), model, main.args)
# Out:
# /home/lingqi/.local/lib/python3.8/site-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# epoch 0/10
# gradient step
# gradient step
# gradient step
# gradient step
# gradient step
# gradient step
# gradient step
# gradient step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a5a60be97cd9> in <module>
# ----> 1 train_denoiser(islvrc.train_set(), model, main.args)
#
# ~/Desktop/denoiser_recon/utils/training.py in train_denoiser(train_set, model, args)
#      33             residual = model(noisy_img)
#      34             loss = criterion(residual, noise)
# ---> 35             loss.backward()
#      36             optimizer.step()
#      37
#
# ~/.local/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
